# %%
# This is the 21 daays challange
## This is the 6th day

# %%
age = 21
if age >= 18:
    print('adult')
# Out:
# adult

# %%
number = 7
if number % 2 ==0:
    print('even')
else:
    print('odd')
# Out:
# odd

# %%
score = 82
if score >= 90:
    grade = 'A'
elif score >= 75:
    grade = 'B'
else:
    grade = 'C'
print(grade)
# Out:
# B

# %%
temperature = 32
if temperature > 35:
    print('hot')
elif temperature >= 20:
    print('comfortable')
else:
    print('cold')
# Out:
# comfortable

# %%
username = 'admin'
password = 'Python123'
print(username == 'admin' and password == 'Python123')
# Out:
# True

# %%
value = 15
print(value > 10 or value < 0)
print(not value == 20)
# Out:
# True
# True

# %%
balance = 500
withdrawl = 300
if withdrawl <= balance:
    print('transaction approved')
else:
    print('insufficient balance')
# Out:
# transaction approved

# %%
day = 'saturday'
print('weekend' if day in ['saturday', 'sunday'] else 'weekday')
# Out:
# weekend

# %%
items = []
if items:
    print('cart has items')
else:
    print('cart is empty')
# Out:
# cart is empty

# %%
age = 24
has_id = True
if age >= 18 and has_id:
    print('entry allowed')
# Out:
# entry allowed
