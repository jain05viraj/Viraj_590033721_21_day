# %%
# This is the 21 days challange
## this is the 2nd day.

# %%
message = '  Learn Coding  '
print(message.strip())
# Out:
# Learn Coding

# %%
word = 'notebooks'
print(word[0],word[-1])
# Out:
# n s

# %%
text = 'programmer'
print(text[0:6])
print(text[6:])
# Out:
# progra
# mmer

# %%
csv_line = 'red,green,blue,purple'
print(csv_line.split(','))
# Out:
# ['red', 'green', 'blue', 'purple']

# %%
parts = [ 'Python' , 'is' , 'great' ]
print(' '.join(parts))
# Out:
# Python is great

# %%
sentance = 'python makes data work'
print(sentance.replace('data','applications'))
# Out:
# python makes applications work

# %%
email = 'student@example.com'
print('example' in email)
print(email.endswith('.com'))
# Out:
# True
# True

# %%
name = 'viraj'
print(name.capitalize())
print(name.center(12,'-'))
# Out:
# Viraj
# ---viraj----

# %%
product = 'laptop pro'
price = '55000'
slug = product.replace(' ','-')
print(f'{slug}: Rs.{price:}')
# Out:
# laptop-pro: Rs.55000

# %%
text = 'python'
print(len(text))
print(text[::-1])
# Out:
# 6
# nohtyp
