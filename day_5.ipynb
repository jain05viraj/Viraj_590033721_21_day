# %%
# This is the 21 days challange
## this is the 5th day.

# %%
student = {'name': 'Viraj', 'age': 18}
print(student)
# Out:
# {'name': 'Viraj', 'age': 18}

# %%
student = {'name': 'Viraj'}
student['score'] = 95
print(student)
# Out:
# {'name': 'Viraj', 'score': 95}

# %%
prices = {'pen': 10, 'book': 90}
print(prices['book'])
# Out:
# 90

# %%
profile = {'name': 'viraj'}
print(profile.get('city','unknown'))
# Out:
# unknown

# %%
scores = {'math': 80, 'english': 93, 'science': 85}
print(scores.keys())
print(scores.values())
# Out:
# dict_keys(['math', 'english', 'science'])
# dict_values([80, 93, 85])

# %%
cart = {'tea': 1, 'coffee': 2}
cart['coffee'] =+ 1
print(cart)
# Out:
# {'tea': 1, 'coffee': 1}

# %%
employee = {'name': 'Viraj', 'department': 'Finance'}
for key, value in employee.items():
    print(key, value)
# Out:
# name Viraj
# department Finance

# %%
word = 'banana'
counts = {}
for letter in word:
    counts[letter] = counts.get(letter, 0) + 1
    print(counts)
# Out:
# {'b': 1}
# {'b': 1, 'a': 1}
# {'b': 1, 'a': 1, 'n': 1}
# {'b': 1, 'a': 2, 'n': 1}
# {'b': 1, 'a': 2, 'n': 2}
# {'b': 1, 'a': 3, 'n': 2}

# %%
products = [
    {'name': 'pen', 'price': 10, 'quantity': 3},
    {'name': 'book', 'price': 80, 'quantity': 2}
]
cart_total =sum(item ['price'] * item ['quantity'] for item in products)
print(cart_total)
# Out:
# 190

# %%
settings = {'dark_mode': False}
settings.update({'language': 'english', 'font_size': 14})
print(settings)
# Out:
# {'dark_mode': False, 'language': 'english', 'font_size': 14}
