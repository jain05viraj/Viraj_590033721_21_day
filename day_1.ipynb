# %%
# This is the 21 days challange
## this is the 1st day.

# %%
name = "Viraj Jain"
print(name)
# Out:
# Viraj Jain

# %%
age = 18
city = "Jabalpur"
print("I am", age, "years old and I live in", city)
# Out:
# I am 18 years old and I live in Jabalpur

# %%
a = 10
b = 10.5
c = "10"
d = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
PRICE = 499.99
print(type(PRICE))
# Out:
# <class 'float'>

# %%
x = 10
print(x)
x = 20 
print(x)
# Out:
# 10
# 20

# %%
name = "python"
version = 3
print(name,version)
# Out:
# python 3
