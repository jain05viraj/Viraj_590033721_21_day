# %%
# This is the 21 days challange
## this is the 8th day.

# %%
count = 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
number = 10
while number > 0:
    print(number)
    number -= 2
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
total = 0
number = 1
while number <= 5:
    total += number
    number += 1
    print(total)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
text = 'Python'
index = 0
while index < len(text):
    print(text[index])
    index += 1
# Out:
# P
# y
# t
# h
# o
# n

# %%
number = 1
while number < 20:
    number *= 2
    print(number)
# Out:
# 2
# 4
# 8
# 16
# 32

# %%
items = ['pen', 'book', 'bag']
while items:
    print(items.pop())
# Out:
# bag
# book
# pen

# %%
attempts = 0
while attempts < 3:
    print('attempt', attempts + 1)
    attempts += 1
# Out:
# attempt 1
# attempt 2
# attempt 3

# %%
number = 1
while True:
    if number == 4:
        break
    print(number)
    number += 1
# Out:
# 1
# 2
# 3

# %%
number = 0
while number < 5:
    number += 1
    if number == 3:
        continue
print(number)
# Out:
# 5

# %%
balance = 100
days = 0
while balance < 150:
    balance += 10
    days += 1
    print(days, balance)
# Out:
# 1 110
# 2 120
# 3 130
# 4 140
# 5 150
